# %% [markdown]
# # Spatial Transformer Example with Cluttered MNIST
# <img src="transformers.jpeg" alt="" style="width: 800px; height: 600px;" />
# Image Source: https://www.pinterest.com/sadieziegler123/bumblebee-3/

# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Spatial-Transformer-Example-with-Cluttered-MNIST" data-toc-modified-id="Spatial-Transformer-Example-with-Cluttered-MNIST-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Spatial Transformer Example with Cluttered MNIST</a></div><div class="lev2 toc-item"><a href="#About-Notebook" data-toc-modified-id="About-Notebook-11"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>About Notebook</a></div><div class="lev1 toc-item"><a href="#Part-1:-Set-up" data-toc-modified-id="Part-1:-Set-up-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Part 1: Set-up</a></div><div class="lev2 toc-item"><a href="#Load-APIs" data-toc-modified-id="Load-APIs-21"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Load APIs</a></div><div class="lev2 toc-item"><a href="#Load-data" data-toc-modified-id="Load-data-22"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Load data</a></div><div class="lev2 toc-item"><a href="#Turn-labels-from-dense-to-one-hot-representation" data-toc-modified-id="Turn-labels-from-dense-to-one-hot-representation-23"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Turn labels from dense to one hot representation</a></div><div class="lev1 toc-item"><a href="#Part-2:-Problem" data-toc-modified-id="Part-2:-Problem-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Part 2: Problem</a></div><div class="lev1 toc-item"><a href="#Part-3:-Localization-Network" data-toc-modified-id="Part-3:-Localization-Network-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Part 3: Localization Network</a></div><div class="lev2 toc-item"><a href="#Create-placeholders" data-toc-modified-id="Create-placeholders-41"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Create placeholders</a></div><div class="lev2 toc-item"><a href="#Reshape-inputs" data-toc-modified-id="Reshape-inputs-42"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Reshape inputs</a></div><div class="lev2 toc-item"><a href="#Setup-a-two-layer-localisation-network" data-toc-modified-id="Setup-a-two-layer-localisation-network-43"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Setup a two-layer localisation network</a></div><div class="lev2 toc-item"><a href="#Define-a-two-layer-localisation-network" data-toc-modified-id="Define-a-two-layer-localisation-network-44"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Define a two layer localisation network</a></div><div class="lev2 toc-item"><a href="#Create-a-spatial-transformer-module" data-toc-modified-id="Create-a-spatial-transformer-module-45"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Create a spatial transformer module</a></div><div class="lev1 toc-item"><a href="#Part-4:-Convolutional-Layers" data-toc-modified-id="Part-4:-Convolutional-Layers-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Part 4: Convolutional Layers</a></div><div class="lev2 toc-item"><a href="#Build-the-first-layer-of-convolution" data-toc-modified-id="Build-the-first-layer-of-convolution-51"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Build the first layer of convolution</a></div><div class="lev2 toc-item"><a href="#Build-the-second-layer-of-convolution" data-toc-modified-id="Build-the-second-layer-of-convolution-52"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Build the second layer of convolution</a></div><div class="lev2 toc-item"><a href="#Connect-the-convolutional-layers-with-a-fully-connected-layer" data-toc-modified-id="Connect-the-convolutional-layers-with-a-fully-connected-layer-53"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Connect the convolutional layers with a fully-connected layer</a></div><div class="lev2 toc-item"><a href="#Add-a-softmax-layer-for-predicted-probabilities" data-toc-modified-id="Add-a-softmax-layer-for-predicted-probabilities-54"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Add a softmax layer for predicted probabilities</a></div><div class="lev1 toc-item"><a href="#Part-5:-Loss,-Optimization,-and-Evalution" data-toc-modified-id="Part-5:-Loss,-Optimization,-and-Evalution-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Part 5: Loss, Optimization, and Evalution</a></div><div class="lev2 toc-item"><a href="#Define-loss-and-optimizer" data-toc-modified-id="Define-loss-and-optimizer-61"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Define loss and optimizer</a></div><div class="lev2 toc-item"><a href="#Monitor-accuracy" data-toc-modified-id="Monitor-accuracy-62"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Monitor accuracy</a></div><div class="lev1 toc-item"><a href="#Part-6:-Create-and-Run-Session" data-toc-modified-id="Part-6:-Create-and-Run-Session-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Part 6: Create and Run Session</a></div><div class="lev2 toc-item"><a href="#Initialize-session" data-toc-modified-id="Initialize-session-71"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Initialize session</a></div><div class="lev2 toc-item"><a href="#Train-parameters" data-toc-modified-id="Train-parameters-72"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Train parameters</a></div><div class="lev2 toc-item"><a href="#Train-model" data-toc-modified-id="Train-model-73"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Train model</a></div><div class="lev1 toc-item"><a href="#Part-7:-Evaluate" data-toc-modified-id="Part-7:-Evaluate-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Part 7: Evaluate</a></div><div class="lev2 toc-item"><a href="#Accuracy" data-toc-modified-id="Accuracy-81"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Accuracy</a></div><div class="lev2 toc-item"><a href="#Inspect-results" data-toc-modified-id="Inspect-results-82"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Inspect results</a></div>

# %% [markdown]
# ## About Notebook
#
# __Orginal Source:__ https://github.com/tensorflow/models/blob/master/transformer/cluttered_mnist.py
#
# __Goal:__ Demonstrate spatial transformer networks use case with tensorflow.
#
# __Actions:__
#
# - Re-annotate orginal source for easier consumption.
#
# - Include visual represention of inputs and predictions.
#
# - Blog about [experience](https://medium.com/wonks-this-way/spatial-transformer-networks-with-tensorflow-2eaed0374a16#.2emq15acn).
#
# __Audience:__ Intermediate level Tensorflow users.

# %% [markdown]
# # Part 1: Set-up

# %% [markdown]
# ## Load APIs

# %%
import tensorflow as tf
from spatial_transformer import transformer
import numpy as np
from tf_utils import weight_variable, bias_variable, dense_to_one_hot
import matplotlib.pylab as plt
from datetime import datetime
# %matplotlib inline

# %% [markdown]
# ## Load data

# %%
mnist_cluttered = np.load('./data/mnist_sequence1_sample_5distortions5x5.npz')

X_train = mnist_cluttered['X_train']
y_train = mnist_cluttered['y_train']
X_valid = mnist_cluttered['X_valid']
y_valid = mnist_cluttered['y_valid']
X_test = mnist_cluttered['X_test']
y_test = mnist_cluttered['y_test']

# %% [markdown]
# ## Turn labels from dense to one hot representation

# %%
Y_train = dense_to_one_hot(y_train, n_classes=10)
Y_valid = dense_to_one_hot(y_valid, n_classes=10)
Y_test = dense_to_one_hot(y_test, n_classes=10)

# %% [markdown]
# # Part 2: Problem

# %%
np.random.seed = 99
example_indices = np.random.randint(1, 1000, size=20)

ith = 0
plt.rcParams['figure.figsize'] = (16.0, 16.0)
plt.subplots_adjust(wspace=0, hspace=.2)
for index in example_indices:
    
    plt.subplot(5, 4, ith+1)
    plt.imshow(mnist_cluttered['X_test'].reshape(1000, 40, 40)[index, ...])
    
    truth = mnist_cluttered['y_test'][index][0]

    plt.title("Image: {}, Label: {}, Prediction: ?".format(index, truth), {'fontsize': 10})
    plt.axis('off')
    ith += 1

# %% [markdown]
# # Part 3: Localization Network

# %% [markdown]
# ## Create placeholders
#
# __Key idea:__
#
# Placeholders for 40x40 resolution input images.

# %%
tf.set_random_seed(1)
x = tf.placeholder(tf.float32, [None, 1600])
y = tf.placeholder(tf.float32, [None, 10])

# %% [markdown]
# ## Reshape inputs
#
# __Key idea:__
#
# Since x is currently [batch, height*width], we need to reshape to a
# 4-D tensor to use it in a convolutional graph.  If one component of
# `shape` is the special value -1, the size of that dimension is
# computed so that the total size remains constant.  Since we haven't
# defined the batch dimension's shape yet, we use -1 to denote this
# dimension should not change size.

# %%
x_tensor = tf.reshape(x, [-1, 40, 40, 1])

# %% [markdown]
# ## Setup a two-layer localisation network
#
# __Key idea:__
#
# Setup the two-layer localisation network to figure out the parameters for an affine transformation of the input.  Use identity transformation as starting point.

# %%
# Identity transformation
initial = np.array([[1., 0, 0], [0, 1., 0]])
initial = initial.astype('float32')
initial = initial.flatten()

# Create variables for fully connected layer for the localisation network
W_fc_loc1 = weight_variable([1600, 20])
b_fc_loc1 = bias_variable([20])

W_fc_loc2 = weight_variable([20, 6])
b_fc_loc2 = tf.Variable(initial_value=initial, name='b_fc_loc2')

# %% [markdown]
# ## Define a two layer localisation network
#
# __Key idea:__
#
# Use activation function (Tanh) for first and second local layers.  Add regularization technique (dropout) in anticipation for overfitting.

# %%
# Frist layer
h_fc_loc1 = tf.nn.tanh(tf.matmul(x, W_fc_loc1) + b_fc_loc1)

# Dropout for regularization
keep_prob = tf.placeholder(tf.float32)
h_fc_loc1_drop = tf.nn.dropout(h_fc_loc1, keep_prob)

# Second layer
h_fc_loc2 = tf.nn.tanh(tf.matmul(h_fc_loc1_drop, W_fc_loc2) + b_fc_loc2)

# %% [markdown]
# ## Create a spatial transformer module

# %%
out_size = (40, 40)
h_trans = transformer(x_tensor, h_fc_loc2, out_size)

# %% [markdown]
# # Part 4: Convolutional Layers
#
# __Key idea:__
#
# Design a simple two layer convolutional network. This arbitrary, so you can experiment with different structures!

# %% [markdown]
# ## Build the first layer of convolution
#
# __Key idea:__
#
# Define our stride as batch x height x width x channels instead of pooling, we use strides of 2 and more layers with smaller filters.

# %%
# Weight matrix is [height x width x input_channels x output_channels]
filter_size = 3
n_filters_1 = 16
W_conv1 = weight_variable([filter_size, filter_size, 1, n_filters_1])

# Bias is [output_channels]
b_conv1 = bias_variable([n_filters_1])

# Activation Function
h_conv1 = tf.nn.relu(
    tf.nn.conv2d(input=h_trans, filter=W_conv1, strides=[1, 2, 2, 1], padding='SAME') + b_conv1)

# %% [markdown]
# ## Build the second layer of convolution

# %%
n_filters_2 = 16
W_conv2 = weight_variable([filter_size, filter_size, n_filters_1, n_filters_2])
b_conv2 = bias_variable([n_filters_2])
h_conv2 = tf.nn.relu(
    tf.nn.conv2d(input=h_conv1, filter=W_conv2, strides=[1, 2, 2, 1], padding='SAME') + b_conv2)

# %% [markdown]
# ## Connect the convolutional layers with a fully-connected layer

# %%
# Reshape to the fully-connected layer
h_conv2_flat = tf.reshape(h_conv2, [-1, 10 * 10 * n_filters_2])

# Create the fully-connected layer
n_fc = 1024
W_fc1 = weight_variable([10 * 10 * n_filters_2, n_fc])
b_fc1 = bias_variable([n_fc])
h_fc1 = tf.nn.relu(tf.matmul(h_conv2_flat, W_fc1) + b_fc1)

# Add additional regularization
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# %% [markdown]
# ## Add a softmax layer for predicted probabilities

# %%
W_fc2 = weight_variable([n_fc, 10])
b_fc2 = bias_variable([10])
y_logits = tf.matmul(h_fc1_drop, W_fc2) + b_fc2
scores = tf.nn.softmax_cross_entropy_with_logits(logits=y_logits, labels=y)

# %% [markdown]
# # Part 5: Loss, Optimization, and Evalution

# %% [markdown]
# ## Define loss and optimizer

# %%
# Loss
cross_entropy = tf.reduce_mean(scores)

# Optimizer
opt = tf.train.AdamOptimizer()

# Minimize
optimizer = opt.minimize(cross_entropy)

# Gradients 
grads = opt.compute_gradients(cross_entropy, [b_fc_loc2])

# %% [markdown]
# ## Monitor accuracy

# %%
predictions = tf.argmax(y_logits, 1)
correct_prediction = tf.equal(tf.argmax(y_logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, 'float'))

results_fmt = '[{:%H:%M:%S}] EPOCH {}/{} LOSS {:.3f}, DEV: {:.3f}'

# %% [markdown]
# # Part 6: Create and Run Session
#
# __Key idea:__
#
# Standard tensorflow boilerplate code to create and run a session.

# %% [markdown]
# ## Initialize session

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %% [markdown]
# ## Train parameters

# %%
# We'll now train in minibatches and report accuracy, loss:
iter_per_epoch = 100
n_epochs = 20 # Feel free to increase the epochs for better results
train_size = 10000

indices = np.linspace(0, 10000 - 1, iter_per_epoch)
indices = indices.astype('int')

# %% [markdown]
# ## Train model

# %%
results_fmt = '[{:%H:%M:%S}] EPOCH {}, ITERATION {}/{}, LOSS {:.3f}'

for epoch_i in range(n_epochs):
    for iter_i in range(iter_per_epoch - 1):
        batch_xs = X_train[indices[iter_i]:indices[iter_i + 1]]
        batch_ys = Y_train[indices[iter_i]:indices[iter_i + 1]]

        if iter_i % 10 == 0:
            loss = sess.run(cross_entropy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.0})
            print(results_fmt.format(datetime.now(), epoch_i, iter_i, iter_per_epoch, loss))
            
        sess.run(optimizer, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.8})
        
    val_acc = sess.run(accuracy, feed_dict={x: X_valid, y: Y_valid, keep_prob: 1.0})

    print('--------> {}/{} EPOCHS, VAL ACC: {:.3f}'.format(epoch_i + 1, n_epochs, val_acc))
    
test_acc, test_predictions = sess.run([accuracy, predictions], feed_dict={x: X_test, y: Y_test, keep_prob: 1.0})
#     theta = sess.run(h_fc_loc2, feed_dict={x: batch_xs, keep_prob: 1.0})
#     print(theta[0])
# Out:
# [10:59:25] EPOCH 0, ITERATION 0/100, LOSS 2.302
# [10:59:25] EPOCH 0, ITERATION 10/100, LOSS 2.300
# [10:59:26] EPOCH 0, ITERATION 20/100, LOSS 2.296
# [10:59:26] EPOCH 0, ITERATION 30/100, LOSS 2.302
# [10:59:27] EPOCH 0, ITERATION 40/100, LOSS 2.299
# [10:59:27] EPOCH 0, ITERATION 50/100, LOSS 2.287
# [10:59:28] EPOCH 0, ITERATION 60/100, LOSS 2.288
# [10:59:29] EPOCH 0, ITERATION 70/100, LOSS 2.239
# [10:59:29] EPOCH 0, ITERATION 80/100, LOSS 2.227
# [10:59:30] EPOCH 0, ITERATION 90/100, LOSS 2.151
# --------> 1/20 EPOCHS, VAL ACC: 0.242
# [10:59:30] EPOCH 1, ITERATION 0/100, LOSS 2.079
# [10:59:31] EPOCH 1, ITERATION 10/100, LOSS 2.000
# [10:59:31] EPOCH 1, ITERATION 20/100, LOSS 1.845
# [10:59:32] EPOCH 1, ITERATION 30/100, LOSS 1.727
# [10:59:33] EPOCH 1, ITERATION 40/100, LOSS 1.548
# [10:59:33] EPOCH 1, ITERATION 50/100, LOSS 1.542
# [10:59:34] EPOCH 1, ITERATION 60/100, LOSS 1.416
# [10:59:34] EPOCH 1, ITERATION 70/100, LOSS 1.391
# [10:59:35] EPOCH 1, ITERATION 80/100, LOSS 1.331
# [10:59:35] EPOCH 1, ITERATION 90/100, LOSS 0.958
# --------> 2/20 EPOCHS, VAL ACC: 0.684
# [10:59:36] EPOCH 2, ITERATION 0/100, LOSS 1.122
# [10:59:37] EPOCH 2, ITERATION 10/100, LOSS 0.978
# [10:59:37] EPOCH 2, ITERATION 20/100, LOSS 0.856
# [10:59:38] EPOCH 2, ITERATION 30/100, LOSS 0.762
# [10:59:38] EPOCH 2, ITERATION 40/100, LOSS 0.672
# [10:59:39] EPOCH 2, ITERATION 50/100, LOSS 0.810
# [10:59:39] EPOCH 2, ITERATION 60/100, LOSS 0.753
# [10:59:40] EPOCH 2, ITERATION 70/100, LOSS 0.674
# [10:59:40] EPOCH 2, ITERATION 80/100, LOSS 0.705
# [10:59:41] EPOCH 2, ITERATION 90/100, LOSS 0.540
# --------> 3/20 EPOCHS, VAL ACC: 0.835
# [10:59:42] EPOCH 3, ITERATION 0/100, LOSS 0.632
# [10:59:42] EPOCH 3, ITERATION 10/100, LOSS 0.556
# [10:59:43] EPOCH 3, ITERATION 20/100, LOSS 0.519
# [10:59:43] EPOCH 3, ITERATION 30/100, LOSS 0.455
# [10:59:44] EPOCH 3, ITERATION 40/100, LOSS 0.376
# [10:59:45] EPOCH 3, ITERATION 50/100, LOSS 0.638
# [10:59:45] EPOCH 3, ITERATION 60/100, LOSS 0.521
# [10:59:46] EPOCH 3, ITERATION 70/100, LOSS 0.577
# [10:59:46] EPOCH 3, ITERATION 80/100, LOSS 0.537
# [10:59:47] EPOCH 3, ITERATION 90/100, LOSS 0.375
# --------> 4/20 EPOCHS, VAL ACC: 0.879
# [10:59:48] EPOCH 4, ITERATION 0/100, LOSS 0.475
# [10:59:48] EPOCH 4, ITERATION 10/100, LOSS 0.324
# [10:59:49] EPOCH 4, ITERATION 20/100, LOSS 0.341
# [10:59:50] EPOCH 4, ITERATION 30/100, LOSS 0.298
# [10:59:50] EPOCH 4, ITERATION 40/100, LOSS 0.308
# [10:59:51] EPOCH 4, ITERATION 50/100, LOSS 0.540
# [10:59:51] EPOCH 4, ITERATION 60/100, LOSS 0.422
# [10:59:52] EPOCH 4, ITERATION 70/100, LOSS 0.455
# [10:59:53] EPOCH 4, ITERATION 80/100, LOSS 0.405
# [10:59:53] EPOCH 4, ITERATION 90/100, LOSS 0.320
# --------> 5/20 EPOCHS, VAL ACC: 0.880
# [10:59:54] EPOCH 5, ITERATION 0/100, LOSS 0.492
# [10:59:55] EPOCH 5, ITERATION 10/100, LOSS 0.271
# [10:59:55] EPOCH 5, ITERATION 20/100, LOSS 0.283
# [10:59:56] EPOCH 5, ITERATION 30/100, LOSS 0.216
# [10:59:56] EPOCH 5, ITERATION 40/100, LOSS 0.236
# [10:59:57] EPOCH 5, ITERATION 50/100, LOSS 0.510
# [10:59:58] EPOCH 5, ITERATION 60/100, LOSS 0.383
# [10:59:58] EPOCH 5, ITERATION 70/100, LOSS 0.352
# [10:59:59] EPOCH 5, ITERATION 80/100, LOSS 0.284
# [11:00:00] EPOCH 5, ITERATION 90/100, LOSS 0.294
# --------> 6/20 EPOCHS, VAL ACC: 0.890
# [11:00:01] EPOCH 6, ITERATION 0/100, LOSS 0.328
# [11:00:01] EPOCH 6, ITERATION 10/100, LOSS 0.249
# [11:00:02] EPOCH 6, ITERATION 20/100, LOSS 0.217
# [11:00:03] EPOCH 6, ITERATION 30/100, LOSS 0.204
# [11:00:03] EPOCH 6, ITERATION 40/100, LOSS 0.262
# [11:00:04] EPOCH 6, ITERATION 50/100, LOSS 0.444
# [11:00:05] EPOCH 6, ITERATION 60/100, LOSS 0.289
# [11:00:06] EPOCH 6, ITERATION 70/100, LOSS 0.262
# [11:00:06] EPOCH 6, ITERATION 80/100, LOSS 0.226
# [11:00:07] EPOCH 6, ITERATION 90/100, LOSS 0.215
# --------> 7/20 EPOCHS, VAL ACC: 0.909
# [11:00:08] EPOCH 7, ITERATION 0/100, LOSS 0.317
# [11:00:08] EPOCH 7, ITERATION 10/100, LOSS 0.191
# [11:00:09] EPOCH 7, ITERATION 20/100, LOSS 0.176
# [11:00:09] EPOCH 7, ITERATION 30/100, LOSS 0.208
# [11:00:10] EPOCH 7, ITERATION 40/100, LOSS 0.236
# [11:00:10] EPOCH 7, ITERATION 50/100, LOSS 0.392
# [11:00:11] EPOCH 7, ITERATION 60/100, LOSS 0.266
# [11:00:12] EPOCH 7, ITERATION 70/100, LOSS 0.250
# [11:00:12] EPOCH 7, ITERATION 80/100, LOSS 0.227
# [11:00:13] EPOCH 7, ITERATION 90/100, LOSS 0.231
# --------> 8/20 EPOCHS, VAL ACC: 0.908
# [11:00:14] EPOCH 8, ITERATION 0/100, LOSS 0.261
# [11:00:14] EPOCH 8, ITERATION 10/100, LOSS 0.200
# [11:00:15] EPOCH 8, ITERATION 20/100, LOSS 0.180
# [11:00:15] EPOCH 8, ITERATION 30/100, LOSS 0.166
# [11:00:16] EPOCH 8, ITERATION 40/100, LOSS 0.245
# [11:00:17] EPOCH 8, ITERATION 50/100, LOSS 0.427
# [11:00:17] EPOCH 8, ITERATION 60/100, LOSS 0.297
# [11:00:18] EPOCH 8, ITERATION 70/100, LOSS 0.231
# [11:00:18] EPOCH 8, ITERATION 80/100, LOSS 0.203
# [11:00:19] EPOCH 8, ITERATION 90/100, LOSS 0.196
# --------> 9/20 EPOCHS, VAL ACC: 0.908
# [11:00:20] EPOCH 9, ITERATION 0/100, LOSS 0.251
# [11:00:20] EPOCH 9, ITERATION 10/100, LOSS 0.217
# [11:00:21] EPOCH 9, ITERATION 20/100, LOSS 0.159
# [11:00:21] EPOCH 9, ITERATION 30/100, LOSS 0.170
# [11:00:22] EPOCH 9, ITERATION 40/100, LOSS 0.277
# [11:00:23] EPOCH 9, ITERATION 50/100, LOSS 0.308
# [11:00:23] EPOCH 9, ITERATION 60/100, LOSS 0.246
# [11:00:24] EPOCH 9, ITERATION 70/100, LOSS 0.198
# [11:00:24] EPOCH 9, ITERATION 80/100, LOSS 0.182
# [11:00:25] EPOCH 9, ITERATION 90/100, LOSS 0.173
# --------> 10/20 EPOCHS, VAL ACC: 0.914
# [11:00:26] EPOCH 10, ITERATION 0/100, LOSS 0.214
# [11:00:26] EPOCH 10, ITERATION 10/100, LOSS 0.150
# [11:00:27] EPOCH 10, ITERATION 20/100, LOSS 0.166
# [11:00:28] EPOCH 10, ITERATION 30/100, LOSS 0.142
# [11:00:28] EPOCH 10, ITERATION 40/100, LOSS 0.188
# [11:00:29] EPOCH 10, ITERATION 50/100, LOSS 0.296
# [11:00:29] EPOCH 10, ITERATION 60/100, LOSS 0.284
# [11:00:30] EPOCH 10, ITERATION 70/100, LOSS 0.172
# [11:00:30] EPOCH 10, ITERATION 80/100, LOSS 0.169
# [11:00:31] EPOCH 10, ITERATION 90/100, LOSS 0.199
# --------> 11/20 EPOCHS, VAL ACC: 0.919
# [11:00:32] EPOCH 11, ITERATION 0/100, LOSS 0.209
# [11:00:32] EPOCH 11, ITERATION 10/100, LOSS 0.208
# [11:00:33] EPOCH 11, ITERATION 20/100, LOSS 0.171
# [11:00:33] EPOCH 11, ITERATION 30/100, LOSS 0.108
# [11:00:34] EPOCH 11, ITERATION 40/100, LOSS 0.201
# [11:00:34] EPOCH 11, ITERATION 50/100, LOSS 0.328
# [11:00:35] EPOCH 11, ITERATION 60/100, LOSS 0.263
# [11:00:35] EPOCH 11, ITERATION 70/100, LOSS 0.205
# [11:00:36] EPOCH 11, ITERATION 80/100, LOSS 0.127
# [11:00:37] EPOCH 11, ITERATION 90/100, LOSS 0.161
# --------> 12/20 EPOCHS, VAL ACC: 0.918
# [11:00:37] EPOCH 12, ITERATION 0/100, LOSS 0.180
# [11:00:38] EPOCH 12, ITERATION 10/100, LOSS 0.139
# [11:00:39] EPOCH 12, ITERATION 20/100, LOSS 0.178
# [11:00:39] EPOCH 12, ITERATION 30/100, LOSS 0.143
# [11:00:40] EPOCH 12, ITERATION 40/100, LOSS 0.211
# [11:00:40] EPOCH 12, ITERATION 50/100, LOSS 0.337
# [11:00:41] EPOCH 12, ITERATION 60/100, LOSS 0.302
# [11:00:42] EPOCH 12, ITERATION 70/100, LOSS 0.154
# [11:00:42] EPOCH 12, ITERATION 80/100, LOSS 0.142
# [11:00:43] EPOCH 12, ITERATION 90/100, LOSS 0.171
# --------> 13/20 EPOCHS, VAL ACC: 0.928
# [11:00:43] EPOCH 13, ITERATION 0/100, LOSS 0.203
# [11:00:44] EPOCH 13, ITERATION 10/100, LOSS 0.138
# [11:00:45] EPOCH 13, ITERATION 20/100, LOSS 0.149
# [11:00:45] EPOCH 13, ITERATION 30/100, LOSS 0.098
# [11:00:46] EPOCH 13, ITERATION 40/100, LOSS 0.168
# [11:00:46] EPOCH 13, ITERATION 50/100, LOSS 0.264
# [11:00:47] EPOCH 13, ITERATION 60/100, LOSS 0.211
# [11:00:47] EPOCH 13, ITERATION 70/100, LOSS 0.173
# [11:00:48] EPOCH 13, ITERATION 80/100, LOSS 0.123
# [11:00:48] EPOCH 13, ITERATION 90/100, LOSS 0.130
# --------> 14/20 EPOCHS, VAL ACC: 0.914
# [11:00:49] EPOCH 14, ITERATION 0/100, LOSS 0.255
# [11:00:50] EPOCH 14, ITERATION 10/100, LOSS 0.119
# [11:00:50] EPOCH 14, ITERATION 20/100, LOSS 0.129
# [11:00:51] EPOCH 14, ITERATION 30/100, LOSS 0.119
# [11:00:51] EPOCH 14, ITERATION 40/100, LOSS 0.160
# [11:00:52] EPOCH 14, ITERATION 50/100, LOSS 0.223
# [11:00:52] EPOCH 14, ITERATION 60/100, LOSS 0.188
# [11:00:53] EPOCH 14, ITERATION 70/100, LOSS 0.099
# [11:00:53] EPOCH 14, ITERATION 80/100, LOSS 0.113
# [11:00:54] EPOCH 14, ITERATION 90/100, LOSS 0.175
# --------> 15/20 EPOCHS, VAL ACC: 0.930
# [11:00:55] EPOCH 15, ITERATION 0/100, LOSS 0.133
# [11:00:55] EPOCH 15, ITERATION 10/100, LOSS 0.128
# [11:00:56] EPOCH 15, ITERATION 20/100, LOSS 0.129
# [11:00:56] EPOCH 15, ITERATION 30/100, LOSS 0.134
# [11:00:57] EPOCH 15, ITERATION 40/100, LOSS 0.201
# [11:00:57] EPOCH 15, ITERATION 50/100, LOSS 0.290
# [11:00:58] EPOCH 15, ITERATION 60/100, LOSS 0.168
# [11:00:58] EPOCH 15, ITERATION 70/100, LOSS 0.132
# [11:00:59] EPOCH 15, ITERATION 80/100, LOSS 0.081
# [11:00:59] EPOCH 15, ITERATION 90/100, LOSS 0.119
# --------> 16/20 EPOCHS, VAL ACC: 0.936
# [11:01:00] EPOCH 16, ITERATION 0/100, LOSS 0.104
# [11:01:01] EPOCH 16, ITERATION 10/100, LOSS 0.129
# [11:01:01] EPOCH 16, ITERATION 20/100, LOSS 0.149
# [11:01:02] EPOCH 16, ITERATION 30/100, LOSS 0.096
# [11:01:02] EPOCH 16, ITERATION 40/100, LOSS 0.150
# [11:01:03] EPOCH 16, ITERATION 50/100, LOSS 0.220
# [11:01:04] EPOCH 16, ITERATION 60/100, LOSS 0.224
# [11:01:04] EPOCH 16, ITERATION 70/100, LOSS 0.117
# [11:01:05] EPOCH 16, ITERATION 80/100, LOSS 0.089
# [11:01:05] EPOCH 16, ITERATION 90/100, LOSS 0.099
# --------> 17/20 EPOCHS, VAL ACC: 0.926
# [11:01:06] EPOCH 17, ITERATION 0/100, LOSS 0.114
# [11:01:07] EPOCH 17, ITERATION 10/100, LOSS 0.098
# [11:01:07] EPOCH 17, ITERATION 20/100, LOSS 0.165
# [11:01:08] EPOCH 17, ITERATION 30/100, LOSS 0.062
# [11:01:08] EPOCH 17, ITERATION 40/100, LOSS 0.117
# [11:01:09] EPOCH 17, ITERATION 50/100, LOSS 0.204
# [11:01:09] EPOCH 17, ITERATION 60/100, LOSS 0.182
# [11:01:10] EPOCH 17, ITERATION 70/100, LOSS 0.147
# [11:01:10] EPOCH 17, ITERATION 80/100, LOSS 0.123
# [11:01:11] EPOCH 17, ITERATION 90/100, LOSS 0.133
# --------> 18/20 EPOCHS, VAL ACC: 0.939
# [11:01:12] EPOCH 18, ITERATION 0/100, LOSS 0.161
# [11:01:12] EPOCH 18, ITERATION 10/100, LOSS 0.075
# [11:01:13] EPOCH 18, ITERATION 20/100, LOSS 0.140
# [11:01:13] EPOCH 18, ITERATION 30/100, LOSS 0.079
# [11:01:14] EPOCH 18, ITERATION 40/100, LOSS 0.092
# [11:01:14] EPOCH 18, ITERATION 50/100, LOSS 0.150
# [11:01:15] EPOCH 18, ITERATION 60/100, LOSS 0.215
# [11:01:16] EPOCH 18, ITERATION 70/100, LOSS 0.136
# [11:01:16] EPOCH 18, ITERATION 80/100, LOSS 0.102
# [11:01:17] EPOCH 18, ITERATION 90/100, LOSS 0.111
# --------> 19/20 EPOCHS, VAL ACC: 0.930
# [11:01:17] EPOCH 19, ITERATION 0/100, LOSS 0.130
# [11:01:18] EPOCH 19, ITERATION 10/100, LOSS 0.089
# [11:01:19] EPOCH 19, ITERATION 20/100, LOSS 0.128
# [11:01:19] EPOCH 19, ITERATION 30/100, LOSS 0.099
# [11:01:20] EPOCH 19, ITERATION 40/100, LOSS 0.086
# [11:01:20] EPOCH 19, ITERATION 50/100, LOSS 0.161
# [11:01:21] EPOCH 19, ITERATION 60/100, LOSS 0.175
# [11:01:21] EPOCH 19, ITERATION 70/100, LOSS 0.088
# [11:01:22] EPOCH 19, ITERATION 80/100, LOSS 0.098
# [11:01:23] EPOCH 19, ITERATION 90/100, LOSS 0.104
# --------> 20/20 EPOCHS, VAL ACC: 0.932

# %% [markdown]
# # Part 7: Evaluate

# %% [markdown]
# ## Accuracy

# %%
test_acc, test_predictions = sess.run([accuracy, predictions], feed_dict={x: X_test, y: Y_test, keep_prob: 1.0})
print(test_acc)
# Out:
# 0.931

# %% [markdown]
# ## Inspect results

# %%
ith = 0
plt.rcParams['figure.figsize'] = (16.0, 16.0)
plt.subplots_adjust(wspace=0, hspace=.2)
for index in example_indices:
    
    plt.subplot(5, 4, ith+1)
    plt.imshow(mnist_cluttered['X_test'].reshape(1000, 40, 40)[index, ...])
    
    truth = mnist_cluttered['y_test'][index][0]
    pred = test_predictions[index]

    if truth == pred:
        label_color = 'black'
    else:
        label_color = 'red'

    plt.title("Image: {}, Label: {}, Prediction: {}".format(index, truth, pred), {'fontsize': 10},  color=label_color)
    plt.axis('off')
    ith += 1
